# %% [markdown]
# # New Section

# %%
import kagglehub
kazanova_sentiment140_path = kagglehub.dataset_download('kazanova/sentiment140')
kashishparmar02_social_media_sentiments_analysis_dataset_path = kagglehub.dataset_download('kashishparmar02/social-media-sentiments-analysis-dataset')
prakharrathi25_google_play_store_reviews_path = kagglehub.dataset_download('prakharrathi25/google-play-store-reviews')

print('Data source import complete.')
# Out:
# Data source import complete.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import nltk
nltk.download('maxent_ne_chunker_tab')
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('words')
nltk.download('vader_lexicon')
from nltk import word_tokenize , pos_tag
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     C:\Users\Dyspro\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Dyspro\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\Dyspro\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\Dyspro\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Dyspro\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
df = df = pd.read_csv(r"C:\Users\Dyspro\.cache\kagglehub\datasets\prakharrathi25\google-play-store-reviews\versions\1\reviews.csv")
print(df.shape)
df = df.head(1000)
print(df.shape)
# Out:
# (12495, 12)
# (1000, 12)

# %%
df.head(10)
# Out:
#                                             reviewId  \
# 0  gp:AOqpTOEhZuqSqqWnaKRgv-9ABYdajFUB0WugPGh-SG-...
# 1  gp:AOqpTOH0WP4IQKBZ2LrdNmFy_YmpPCVrV3diEU9KGm3...
# 2  gp:AOqpTOEMCkJB8Iq1p-r9dPwnSYadA5BkPWTf32Z1azu...
# 3  gp:AOqpTOGFrUWuKGycpje8kszj3uwHN6tU_fd4gLVFy9z...
# 4  gp:AOqpTOHls7DW8wmDFzTkHwxuqFkdNQtKHmO6Pt9jhZE...
# 5  gp:AOqpTOEvElPsBa6k8rLDmk-WrEoJea98KUrIGYWodJe...
# 6  gp:AOqpTOGHb-APKKMNFyL1OwuGq1AGW6bQp5aYYxSHvJx...
# 7  gp:AOqpTOEcxvv_c0CK3G5tHjxXsGSjbzD65OQ3og02p-q...
# 8  gp:AOqpTOHVgr7_qOhORsfPwnVCqX-n98dJ1Ksrps6q52p...
# 9  gp:AOqpTOHQ_paQ_ffWsMqGOWmMsPxs-pBkBgR_3H63WJv...
#
#                            userName  \
# 0                          Eric Tie
# 1                        john alpha
# 2                       Sudhakar .S
# 3  SKGflorida@bellsouth.net DAVID S
# 4                     Louann Stoker
# 5                       Jon Clemens
# 6                            Gale W
# 7                            No One
# 8           I Dewa Gede Nopi Ariana
# 9                       John Riddle
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/AOh14...
# 1  https://play-lh.googleusercontent.com/a-/AOh14...
# 2  https://play-lh.googleusercontent.com/a-/AOh14...
# 3  https://play-lh.googleusercontent.com/-75aK0WF...
# 4  https://play-lh.googleusercontent.com/-pBcY_Z-...
# 5  https://play-lh.googleusercontent.com/-q6L1fx0...
# 6  https://play-lh.googleusercontent.com/a-/AOh14...
# 7  https://play-lh.googleusercontent.com/a-/AOh14...
# 8  https://play-lh.googleusercontent.com/a-/AOh14...
# 9  https://play-lh.googleusercontent.com/a-/AOh14...
#
#                                              content  score  thumbsUpCount  \
# 0                      I cannot open the app anymore      1              0
# 1  I have been begging for a refund from this app...      1              0
# 2  Very costly for the premium version (approx In...      1              0
# 3  Used to keep me organized, but all the 2020 UP...      1              0
# 4                                Dan Birthday Oct 28      1              0
# 5  It has changed how I viewed my different lists...      1              1
# 6  I'm only looking for a grocery list app but ev...      1              0
# 7  Reset my free trial, new phone I'd like to see...      1              0
# 8  How do to stop monthly payment because i don't...      1              0
# 9  I complain about not crashes and it was immedi...      1              1
#
#   reviewCreatedVersion                   at  \
# 0              5.4.0.6  2020-10-27 21:24:41
# 1                  NaN  2020-10-27 14:03:28
# 2                  NaN  2020-10-27 08:18:40
# 3                  NaN  2020-10-26 13:28:07
# 4              5.6.0.7  2020-10-26 06:10:50
# 5              5.6.0.7  2020-10-26 05:04:20
# 6              5.6.0.6  2020-10-25 23:40:46
# 7              5.5.0.8  2020-10-25 19:18:13
# 8              5.6.0.7  2020-10-25 10:09:00
# 9              5.6.0.7  2020-10-23 03:15:01
#
#                                         replyContent            repliedAt  \
# 0                                                NaN                  NaN
# 1  Please note that from checking our records, yo...  2020-10-27 15:05:52
# 2                                                NaN                  NaN
# 3  What do you find troublesome about the update?...  2020-10-26 14:58:29
# 4                                                NaN                  NaN
# 5  Please note that in order to sort the lists by...  2020-10-26 14:56:25
# 6  Sorry about that. We are not aware of any issu...  2020-10-26 14:53:42
# 7  We have an extensive Help Center detailing how...  2020-10-26 14:43:36
# 8  Please note that you may cancel your subscript...  2020-10-26 14:39:59
# 9  We are unaware of any issues with the app not ...  2020-10-25 17:11:06
#
#   sortOrder      appId
# 0    newest  com.anydo
# 1    newest  com.anydo
# 2    newest  com.anydo
# 3    newest  com.anydo
# 4    newest  com.anydo
# 5    newest  com.anydo
# 6    newest  com.anydo
# 7    newest  com.anydo
# 8    newest  com.anydo
# 9    newest  com.anydo

# %%
ax = df['score'].value_counts().sort_index()\
  .plot(kind='bar',
        title='Count of Review by star',
        figsize=(10,6))
plt.show()

# %%
example = df['content'][22]
print(example)
# Out:
# They recently started sending spammy notifications every week or so. Please stop.

# %%
tokens = nltk.word_tokenize(example)
tokens[:10]
# Out:
# ['They',
#  'recently',
#  'started',
#  'sending',
#  'spammy',
#  'notifications',
#  'every',
#  'week',
#  'or',
#  'so']

# %%
tagged = nltk.pos_tag(tokens)
tagged[:10]
# Out:
# [('They', 'PRP'),
#  ('recently', 'RB'),
#  ('started', 'VBD'),
#  ('sending', 'VBG'),
#  ('spammy', 'NN'),
#  ('notifications', 'NNS'),
#  ('every', 'DT'),
#  ('week', 'NN'),
#  ('or', 'CC'),
#  ('so', 'RB')]

# %%
entities = nltk.chunk.ne_chunk(tagged)
entities.pprint()
# Out:
# (S
#   They/PRP
#   recently/RB
#   started/VBD
#   sending/VBG
#   spammy/NN
#   notifications/NNS
#   every/DT
#   week/NN
#   or/CC
#   so/RB
#   ./.
#   Please/NNP
#   stop/NN
#   ./.)

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm
sia = SentimentIntensityAnalyzer()

# %% [markdown]
# ### Recalculate sentiment scores for the expanded DataFrame
#
# Since `df` now contains 1000 rows, we need to re-calculate the sentiment scores for all these reviews before merging them into `vaders`.

# %%
res = {}
for i, row in tqdm(df.iterrows(), total=len(df)):
    text = row['content']
    res[i] = sia.polarity_scores(text)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %% [markdown]
# ### Recreate the `vaders` DataFrame
#
# Now that `res` is updated, we can recreate the `vaders` DataFrame by merging the new sentiment scores with the `df`.

# %%
vaders = pd.DataFrame(res).T
vaders = vaders.reset_index().rename(columns={'index': 'Id'})
vaders = vaders.merge(df, left_on='Id', right_index=True, how='left')
display(vaders.head())
# Out:
#    Id    neg    neu    pos  compound  \
# 0   0  0.000  1.000  0.000    0.0000
# 1   1  0.000  1.000  0.000    0.0000
# 2   2  0.042  0.809  0.149    0.6597
# 3   3  0.202  0.772  0.026   -0.8576
# 4   4  0.000  1.000  0.000    0.0000
#
#                                             reviewId  \
# 0  gp:AOqpTOEhZuqSqqWnaKRgv-9ABYdajFUB0WugPGh-SG-...
# 1  gp:AOqpTOH0WP4IQKBZ2LrdNmFy_YmpPCVrV3diEU9KGm3...
# 2  gp:AOqpTOEMCkJB8Iq1p-r9dPwnSYadA5BkPWTf32Z1azu...
# 3  gp:AOqpTOGFrUWuKGycpje8kszj3uwHN6tU_fd4gLVFy9z...
# 4  gp:AOqpTOHls7DW8wmDFzTkHwxuqFkdNQtKHmO6Pt9jhZE...
#
#                            userName  \
# 0                          Eric Tie
# 1                        john alpha
# 2                       Sudhakar .S
# 3  SKGflorida@bellsouth.net DAVID S
# 4                     Louann Stoker
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/AOh14...
# 1  https://play-lh.googleusercontent.com/a-/AOh14...
# 2  https://play-lh.googleusercontent.com/a-/AOh14...
# 3  https://play-lh.googleusercontent.com/-75aK0WF...
# 4  https://play-lh.googleusercontent.com/-pBcY_Z-...
#
#                                              content  score  thumbsUpCount  \
# 0                      I cannot open the app anymore      1              0
# 1  I have been begging for a refund from this app...      1              0
# 2  Very costly for the premium version (approx In...      1              0
# 3  Used to keep me organized, but all the 2020 UP...      1              0
# 4                                Dan Birthday Oct 28      1              0
#
#   reviewCreatedVersion                   at  \
# 0              5.4.0.6  2020-10-27 21:24:41
# 1                  NaN  2020-10-27 14:03:28
# 2                  NaN  2020-10-27 08:18:40
# 3                  NaN  2020-10-26 13:28:07
# 4              5.6.0.7  2020-10-26 06:10:50
#
#                                         replyContent            repliedAt  \
# 0                                                NaN                  NaN
# 1  Please note that from checking our records, yo...  2020-10-27 15:05:52
# 2                                                NaN                  NaN
# 3  What do you find troublesome about the update?...  2020-10-26 14:58:29
# 4                                                NaN                  NaN
#
#   sortOrder      appId
# 0    newest  com.anydo
# 1    newest  com.anydo
# 2    newest  com.anydo
# 3    newest  com.anydo
# 4    newest  com.anydo

# %%
sia.polarity_scores('I am so happy ')
# Out:
# {'neg': 0.0, 'neu': 0.334, 'pos': 0.666, 'compound': 0.6115}

# %%
sia.polarity_scores('This is the worst thing ever')
# Out:
# {'neg': 0.451, 'neu': 0.549, 'pos': 0.0, 'compound': -0.6249}

# %%
sia.polarity_scores(example)
# Out:
# {'neg': 0.16, 'neu': 0.646, 'pos': 0.193, 'compound': 0.1313}

# %%
vaders = pd.DataFrame(res).T
vaders = vaders.reset_index().rename(columns={'index': '
# 37  gp:AOqpTOHNusAljGcpakkhtaqnBcPbanOnh-su80zKE-S...
# 38  gp:AOqpTOGeRg_WF8424EZFALPqFgTsiPq2IoG0ujnvWKW...
# 39  gp:AOqpTOEnjPfKOVEqfEIiIkjR84JAy8fLppi2ymm9Ef_...
# 40  gp:AOqpTOGn0MEvKawi61Jm2oaqB4M2Wnlc7iJ9l4ivB7c...
# 41  gp:AOqpTOFPubbwFNvEzPdsOdcP0iqJQnQIXWhrOkHZogj...
# 42  gp:AOqpTOE_bX0sDD1eKPnFuOc7wNaL-FHF5OOvSn2qUJD...
# 43  gp:AOqpTOE9ru-RbquL4E0mbskJ_YUKAbQ7woMWT8B7dj_...
# 44  gp:AOqpTOFP85mePEfX4Kx10XxhLtjsiSUfM0HCvHe-88f...
# 45  gp:AOqpTOEBTFvIHE1WHlXoek-nYi1mfnweWC-gM0nJE-n...
# 46  gp:AOqpTOFoIsCA0OHQapg_cPjxZ1c-llzTF8d3Ech31GR...
# 47  gp:AOqpTOEo9Bz_U4tuiFP3J2RBxcSHhUANIV7bNsb2EDN...
# 48  gp:AOqpTOENw2ZRvJuSBJHA-qRQYBi1gYShQy-1aq6bIRy...
# 49  gp:AOqpTOHa_AUcoRKu1nUf7wDYKUM6ddyqObyPHCQPWsT...
#
#                             userName  \
# 0                           Eric Tie
# 1                         john alpha
# 2                        Sudhakar .S
# 3   SKGflorida@bellsouth.net DAVID S
# 4                      Louann Stoker
# 5                        Jon Clemens
# 6                             Gale W
# 7                             No One
# 8            I Dewa Gede Nopi Ariana
# 9                        John Riddle
# 10                       Lisa Pappas
# 11                        Kyuhwa Lee
# 12                      Tom Dashiell
# 13                           Erica M
# 14                    Susan Anderson
# 15                           Simon H
# 16            John Pires Photography
# 17                       Stacy Dehut
# 18                       Rishi Mehta
# 19                    Jacob Lombardi
# 20                 Colleen McFarland
# 21                      Kofi Osahene
# 22                     Chris Warrick
# 23                   Tuukka Rinkinen
# 24                        Gvidas Man
# 25                     A Google user
# 26                      Tim Williams
# 27                   Siddharth Sinha
# 28                      jayesh patel
# 29                          Vân Trần
# 30                   Tony Wu Channel
# 31                     Neil Harrison
# 32                     Gavin Kalavik
# 33                 Thea Dadunashvili
# 34                       Fouad Kraim
# 35                      Patric Hogle
# 36             Janier Guerrero Craig
# 37                   kamlesh dhanuka
# 38                  Analyn Canaveral
# 39                     Paras Prakash
# 40                   panasonik sahoo
# 41                   Joshua Martinez
# 42                        Axel Sanon
# 43                      Patty Padden
# 44                         Alex Alex
# 45                        Steve Hart
# 46                     Navaneeth K P
# 47                               Rob
# 48               Official Saket Sahu
# 49                         Zulq Alam
#
#                                             userImage  \
# 0   https://play-lh.googleusercontent.com/a-/AOh14...
# 1   https://play-lh.googleusercontent.com/a-/AOh14...
# 2   https://play-lh.googleusercontent.com/a-/AOh14...
# 3   https://play-lh.googleusercontent.com/-75aK0WF...
# 4   https://play-lh.googleusercontent.com/-pBcY_Z-...
# 6   I'm only looking for a grocery list app but ev...      1              0
# 7   Reset my free trial, new phone I'd like to see...      1              0
# 8   How do to stop monthly payment because i don't...      1              0
# 9   I complain about not crashes and it was immedi...      1              1
# 10  Constant crashing. After reading all the negat...      1             17
# 11  Widgets are useless because they always show a...      1              0
# 12  Horrible app. It doesn't do as described. Abso...      1              0
# 13  Update October 2020: new update deleted all of...      1             20
# 14  Did not realize there was a charge for this ap...      1              0
# 15  Spams notifications of how many tasks other us...      1              0
# 16  Downloaded first thing it trys to do is do a c...      1              0
# 17        No longer works with Alexa. What happened??      1              0
# 18                           it doesn't show any list      1              0
# 19                                    Do not download      1              0
# 20              This app is not what I wanted at all.      1              0
# 21  Unnecessary pop up. Really annoying and counte...      1              0
# 22  They recently started sending spammy notificat...      1              0
# 23  Shows tasks assigned to others in widget. A ma...      1              0
# 24  7 days for free and then you pay. Plus too com...      1              1
# 25  Update: thanks for your response. I would ask ...      1             59
# 26  Expensive paywall preventing access to feature...      1              0
# 27  I was about to pay for this app when I noticed...      1              0
# 28    Worst application no task information on screen      1              0
# 29  I downloaded this app to try for my task list ...      1              0
# 30  Shameless App Ever, Waste Money !!! I have sub...      1              0
# 31  I am not providing email addresses or google o...      1              0
# 32  Uninstalled it as soon as it started sending m...      1              2
# 33  I have subscribed and have been charged for th...      1              3
# 34  Have to pay premium if you want to put multipl...      1              1
# 35  I have tried I installing this on two separate...      1              0
# 36                                        Prayer Ubde      1              0
# 37  such a useless and greedy app only wants money...      1              0
# 38                                         Yes i what      1              0
# 39                                              Waste      1              0
# 40              Really cumbersome, is not easy to use      1              0
# 41        Was charged for the year instead of monthly      1              0
# 42                    Not free, cannot delete account      1              0
# 43                 Will not enable me to unsubscribe!      1              0
# 44                                           Dindigul      1              0
# 45  Latest update deleted all my tasks and lists! ...      1              0
# 46  Features for the free version are just disappo...      1              0
# 47  Locking basic features behind a paywall is kin...      1              0
# 48   Soo awkward i can't able to sign *up* 😭 Sick app      1              0
# 49             Hangs when setting up Google Assistant      1              0
#
#    reviewCreatedVersion                   at  \
# 0               5.4.0.6  2020-10-27 21:24:41
# 1                   NaN  2020-10-27 14:03:28
# 2                   NaN  2020-10-27 08:18:40
# 3                   NaN  2020-10-26 13:28:07
# 4               5.6.0.7  2020-10-26 06:10:50
# 5               5.6.0.7  2020-10-26 05:04:20
# 6               5.6.0.6  2020-10-25 23:40:46
# 7               5.5.0.8  2020-10-25 19:18:13
# 8               5.6.0.7  2020-10-25 10:09:00
# 9               5.6.0.7  2020-10-23 03:15:01
# 10              5.6.0.6  2020-10-21 23:15:24
# 11                  NaN  2020-10-21 16:28:11
# 12                  NaN  2020-10-20 07:14:49
# 13              5.6.0.7  2020-10-20 06:59:02
# 14                  NaN  2020-10-19 13:14:56
# 15                  NaN  2020-10-18 15:03:27
# 16                  NaN  2020-10-18 11:57:21
# 17              5.6.0.6  2020-10-17 16:09:21
# 30  Note that it takes up to 2 hours for the Premi...  2020-10-12 13:57:47
# 31  The app is account-based for years now, in ord...  2020-10-12 13:42:05
# 32                                                NaN                  NaN
# 33  Please note that it takes up to 2 hours for th...  2020-10-11 13:52:53
# 34  Please note that the Advanced recurring remind...  2020-10-11 13:49:12
# 35  Please make sure that you are following the in...  2020-10-08 14:31:11
# 36                                                NaN                  NaN
# 37  We're sorry you feel this way! Our 7 day trial...  2020-10-08 14:21:57
# 38  Was there a specific issue you encountered? We...  2020-10-05 13:49:34
# 39  Was there a specific issue you encountered? We...  2020-10-05 13:49:28
# 40  We have an extensive Help Center detailing how...  2020-10-05 13:47:29
# 41  Please note that Any.do offers several plans, ...  2020-10-05 13:44:48
# 42  90% of the app is completely free, including a...  2020-10-04 13:59:12
# 43  Please note that you may cancel your subscript...  2020-10-04 13:55:06
# 44                                                NaN                  NaN
# 45  Please make sure that you are using the same e...  2020-10-04 13:40:14
# 46  Please note that 90% of the app is completely ...  2020-10-01 13:39:27
# 47  Please note that 90% of the app is completely ...  2020-10-01 13:39:20
# 48  Sorry about that! Kindly contact our Support T...  2020-09-29 12:17:07
# 49  We are unaware of any issues with the integrat...  2020-09-29 11:51:20
#
#    sortOrder      appId
# 0     newest  com.anydo
# 1     newest  com.anydo
# 2     newest  com.anydo
# 3     newest  com.anydo
# 4     newest  com.anydo
# 5     newest  com.anydo
# 6     newest  com.anydo
# 7     newest  com.anydo
# 8     newest  com.anydo
# 9     newest  com.anydo
# 10    newest  com.anydo
# 11    newest  com.anydo
# 12    newest  com.anydo
# 13    newest  com.anydo
# 14    newest  com.anydo
# 15    newest  com.anydo
# 16    newest  com.anydo
# 17    newest  com.anydo
# 18    newest  com.anydo
# 19    newest  com.anydo
# 20    newest  com.anydo
# 21    newest  com.anydo
# 22    newest  com.anydo
# 23    newest  com.anydo
# 24    newest  com.anydo
# 25    newest  com.anydo
# 26    newest  com.anydo
# 27    newest  com.anydo
# 28    newest  com.anydo
# 29    newest  com.anydo
# 30    newest  com.anydo
# 31    newest  com.anydo
# 32    newest  com.anydo
# 33    newest  com.anydo
# 34    newest  com.anydo
# 35    newest  com.anydo
# 36    newest  com.anydo
# 37    newest  com.anydo
# 38    newest  com.anydo
# 39    newest  com.anydo
# 40    newest  com.anydo
# 41    newest  com.anydo
# 42    newest  com.anydo
# 43    newest  com.anydo
# 44    newest  com.anydo
# 45    newest  com.anydo
# 46    newest  com.anydo
# 47    newest  com.anydo
# 48    newest  com.anydo
# 49    newest  com.anydo

# %%
ax= sns.barplot(data = vaders, x='score' , y='compound')
ax.set_title('Compound Score by Sentiment')
plt.show(5)

# %%
fig,axs = plt.subplots(1,3,figsize=(12,3))
sns.barplot(data=vaders,x='score',y='pos',ax=axs[0])
sns.barplot(data=vaders,x='score',y='neu',ax=axs[1])
sns.barplot(data=vaders,x='score',y='neg',ax=axs[2])
axs[0].set_title('Positive')
axs[1].set_title('Neutral')
axs[2].set_title('Negative')
plt.tight_layout()
plt.show()
